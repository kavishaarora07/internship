# %% [markdown]
# # question 6

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r"C:\Users\Kavisha\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
search_product = driver.find_element(By.XPATH,'//input[@class="_3704LK"]')
search_product.send_keys("sneakers")

# %%
search_btn = driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
search_btn.click()

# %%
brand_name = []
product_description = []
price_val = []

# %%
brand_title =  driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_title[0:200]:
    brand= i.text
    brand_name.append(brand)

# %%
product_title= driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product_title[0:200]:
    product = i.text
    product_description.append(product)

# %%
price_tag = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tag[0:200]:
    price = i.text
    price_val.append(price)

# %%
print(len(brand_name),len(product_description),len(price_val))
# Out:
# 40 40 40

# %%
import pandas as pd

# %%
df6 = pd.DataFrame({"brand_name":brand_name,'product_description':product_description,'price_vale':price_val})
df6
# Out:
#                  brand_name  \
# 0                  RapidBox
# 1           U.S. POLO ASSN.
# 2                    Labbin
# 3                    Shozie
# 4                    Kzaara
# 5                       SFR
# 6                       SFR
# 7                  HOTSTYLE
# 8                      aadi
# 9                    BRUTON
# 10              kardam&sons
# 11           Mast & Harbour
# 12                   BRUTON
# 13                      SFR
# 14                SCATCHITE
# 15      World Wear Footwear
# 16                 RapidBox
# 17                     PUMA
# 18                   Kraasa
# 19                Deals4you
# 20                RED CHIEF
# 21              kardam&sons
# 22  Bond Street By Red Tape
# 23                   Rzisbo
# 24                      SFR
# 25                    asian
# 26                     ANTA
# 27                   Footox
# 28                     PUMA
# 29                      GVR
# 30                   Kraasa
# 31              bacca bucci
# 32                       TR
# 33                   Shozie
# 34              Asian Shoes
# 35              Asian Shoes
# 36                     ANTA
# 37                     ANTA
# 38             Robbie jones
# 39             Robbie jones
#
#                                   product_description price_vale
# 0                   Stylish & Trendy Sneakers For Men       ₹599
# 1                         MADRYN 2.O Sneakers For Men     ₹1,869
# 2                                    Sneakers For Men       ₹399
# 3                                    Sneakers For Men       ₹295
# 4                                    Sneakers For Men       ₹229
# 5   PLANCK Smart Grey Lace-Ups Casuals Sneakers Sn...       ₹209
# 6   FAST Trenddy Tainer Lace-ups Sporty Casuals Sn...       ₹299
# 7                   Stylish & Trendy Sneakers For Men       ₹399
# 8   Mesh | Ultralightweight | Comfortable | Breath...       ₹359
# 9   Lightweight Pack Of 1 Trendy Sneakers Sneakers...       ₹249
# 10  Fashionable Canvas Casual Partywear Outdoor Sn...       ₹474
# 11                                   Sneakers For Men       ₹824
# 12      Modern Trendy Sneakers Shoes Sneakers For Men       ₹299
# 13                                   Sneakers For Men       ₹269
# 14                          Sneakers Sneakers For Men       ₹360
# 15  Exclusive Affordable Collection of Trendy & St...       ₹259
# 16                                   Sneakers For Men       ₹599
# 17                 Mirage Sport Tech Sneakers For Men     ₹3,599
# 18        Casuals, Canvas, Partywear Sneakers For Men       ₹449
# 19                                 Sneakers For Women       ₹299
# 20                        RC3522 107 Sneakers For Men     ₹2,804
# 21  Canvas Casual Partywear Outdoor Shoes For Boys...       ₹499
# 22                          High Top Sneakers For Men     ₹1,324
# 23                                   Sneakers For Men       ₹549
# 24  PLANCK Smart Red Lace-Ups Casuals Sneakers Sne...       ₹209
# 25           WATERPROOF-05cFULLWHITE Sneakers For Men       ₹657
# 26                           A-Shock Sneakers For Men     ₹4,509
# 27  Walking Shoes for Men | Running Shoes | Casual...       ₹499
# 28                RS-Connect Ombre T Sneakers For Men     ₹3,850
# 29                                   Sneakers For Men       ₹597
# 30                                 Sneakers For Women       ₹299
# 31  ILLUSION Hi-Top Street Fashion Sneakers with R...     ₹1,799
# 32                                   Sneakers For Men       ₹389
# 33                                   Sneakers For Men       ₹419
# 34  Future-04 casual shoes for men | Latest Stylis...       ₹449
# 35  Future-04 casual shoes for men | Latest Stylis...       ₹449
# 36                                   Sneakers For Men     ₹3,299
# 37                      ULTRA GROOVE Sneakers For Men     ₹2,024
# 38                                   Sneakers For Men       ₹439
# 39                                   Sneakers For Men       ₹439

# %%
start=0
end=2
for page in range(start,end):
    titles= driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
    for i in titles:
        job_titles.append(i.text)
    next_button = driver.find_element(By.XPATH,'//a[@class="fright fs14 btn-secondary br2"]')
    next_button.click()
    time.sleep(3)

# %%
brand_name = []
product_description = []
price_val = []

# %%
start=0
end=2
for page in range(start,end):
    titles= driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in titles:
        brand_name.append(i.text)
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
brand_name
# Out:
# ['RapidBox',
#  'ANTA',
#  'World Wear Footwear',
#  'SFR',
#  'aadi',
#  'PORT',
#  'Allen Cooper',
#  'asian',
#  'RED TAPE',
#  'RED TAPE',
#  'ANTA',
#  'ANTA',
#  'RapidBox',
#  'PUMA',
#  'Dicy',
#  'RED TAPE',
#  'ANTA',
#  'Strollin',
#  'FOOBON',
#  'RINDAS',
#  'VENDOZ',
#  'Layasa',
#  'RapidBox',
#  'RapidBox',
#  'ASTEROID',
#  'Magnolia',
#  'PUMA',
#  'U.S. POLO ASSN.',
#  'Deals4you',
#  'Robbie jones',
#  'U.S. POLO ASSN.',
#  'ANTA',
#  'RED TAPE',
#  'Sparx',
#  'Dizzler',
#  'TRENDUTY',
#  'Mzzideko',
#  'Zixer',
#  'BRUTON',
#  'Kzaara',
#  'Sparx',
#  'Shozie',
#  'Labbin',
#  'Shozie',
#  'Kzaara',
#  'SFR',
#  'SFR',
#  'LishTree',
#  'aadi',
#  'BRUTON',
#  'ANTA',
#  'ANTA',
#  'BRUTON',
#  'SFR',
#  'SCATCHITE',
#  'World Wear Footwear',
#  'PUMA',
#  'PUMA',
#  'Kraasa',
#  'Deals4you',
#  'T-ROCK',
#  'asian',
#  'Bond Street By Red Tape',
#  'Rzisbo',
#  'SFR',
#  'asian',
#  'U.S. POLO ASSN.',
#  'Layasa',
#  'PUMA',
#  'GVR',
#  'ANTA',
#  'CAMPUS',
#  'TR',
#  'Shozie',
#  'Asian Shoes',
#  'Asian Shoes',
#  'ANTA',
#  'U.S. POLO ASSN.',
#  'Robbie jones',
#  'Robbie jones']

# %%
start=0
end=2
for page in range(start,end):
    titles= driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in titles:
        product_description.append(i.text)
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
product_description
# Out:
# ['Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Women',
#  'Court Vision Low Better Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Canvas Casual Partywear Outdoor Shoes For Boys Sneakers...',
#  'ILLUSION Hi-Top Street Fashion Sneakers with Rubber Out...',
#  'Sneakers For Men',
#  'Synthetic| Lightweight| Premiun| Comfort| Summer Tendy|...',
#  'Sneakers For Men',
#  'ULTRA GROOVE Sneakers For Men',
#  'Mirage Sport Tech Sneakers For Men',
#  'Sneakers For Men',
#  'Stylish & Trending Outdoor Walking Comfortable Sneakers...',
#  'LITTLE MILENNIUM Sneakers For Men',
#  'A-Fly Sneakers For Men',
#  'Casual Sneakers White Shoes For Boys And Men Sneakers F...',
#  'Modern Trendy Sneakers Shoes Sneakers For Men',
#  '91CLOUD Sneakers For Men',
#  'MIX1. Sneakers For Men',
#  'Sneakers For Women',
#  'PLANCK Smart Blue Lace-Ups Casuals Sneakers Sneakers Fo...',
#  'Sneakers For Men',
#  'MIX3. Sneakers For Men',
#  'Canvas Casual Partywear Outdoor Shoes For Boys Sneakers...',
#  'PLANCK Smart Sky Lace-Ups Casuals Sneakers Sneakers For...',
#  'Synthetic| Lightweight| Premiun| Comfort| Summer Tendy|...',
#  'Skye Clean Distressed Sneakers For Women',
#  'BRENTT 2.0 Sneakers For Men',
#  'Synthetic| Lightweight| Premiun| Comfort| Summer Tendy|...',
#  'Sneakers For Men',
#  'RTE3673 Sneakers For Men',
#  'Sneakers For Men',
#  'Stylish & Trending Collection Textured Comfortable Snea...',
#  'STREET Sneakers For Men',
#  'Puma Wired Cage Sneakers For Men',
#  'Synthetic Leather Casual Partywear Pvc Sole Shoes For M...',
#  'STREET Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'PLANCK Smart Grey Lace-Ups Casuals Sneakers Sneakers Fo...',
#  'FAST Trenddy Tainer Lace-ups Sporty Casuals Sneakers Fo...',
#  'Sneakers For Women',
#  'Lightweight Pack Of 1 Trendy Sneakers Sneakers For Men',
#  'LUCY Sneakers For Men',
#  'LITTLE G6 Sneakers For Men',
#  'Modern Trendy Sneakers Shoes Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers Sneakers For Men',
#  'Exclusive Affordable Collection of Trendy & Stylish Cas...',
#  'LITTLE MILENNIUM Sneakers For Men',
#  'Sneakers For Men',
#  'Casuals, Canvas, Partywear Sneakers For Men',
#  'Sneakers For Women',
#  'Sneakers For Women',
#  'MAPF1 A3ROCAT Mid Sneakers For Men',
#  'High Top Sneakers For Men',
#  'Sneakers For Men',
#  'PLANCK Smart Red Lace-Ups Casuals Sneakers Sneakers For...',
#  'WATERPROOF-05cFULLWHITE Sneakers For Men',
#  'Venus Sneakers For Women',
#  'Advantage Genz Sneakers For Men Sneakers For Men',
#  'RS-Connect Ombre T Sneakers For Men',
#  'Sneakers For Men',
#  'Jada Renew Sneakers For Women',
#  'Wired SlipOn Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Future-04 casual shoes for men | Latest Stylish Casual ...',
#  'Future-04 casual shoes for men | Latest Stylish Casual ...',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men']

# %%
start=0
end=2
for page in range(start,end):
    titles= driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in titles:
        price_val.append(i.text)
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
price_val
# Out:
# ['₹599',
#  '₹299',
#  '₹299',
#  '₹3,047',
#  '₹299',
#  '₹549',
#  '₹664',
#  '₹499',
#  '₹799',
#  '₹399',
#  '₹1,799',
#  '₹3,299',
#  '₹3,599',
#  '₹599',
#  '₹849',
#  '₹599',
#  '₹2,024',
#  '₹1,997',
#  '₹399',
#  '₹349',
#  '₹2,863',
#  '₹1,912',
#  '₹499',
#  '₹299',
#  '₹209',
#  '₹259',
#  '₹3,142',
#  '₹3,124',
#  '₹209',
#  '₹499',
#  '₹2,884',
#  '₹449',
#  '₹399',
#  '₹1,249',
#  '₹1,143',
#  '₹599',
#  '₹494',
#  '₹2,009',
#  '₹1,750',
#  '₹399',
#  '₹1,749',
#  '₹1,799',
#  '₹399',
#  '₹295',
#  '₹229',
#  '₹209',
#  '₹299',
#  '₹424',
#  '₹359',
#  '₹249',
#  '₹448',
#  '₹2,884',
#  '₹299',
#  '₹269',
#  '₹360',
#  '₹259',
#  '₹2,023',
#  '₹449',
#  '₹449',
#  '₹299',
#  '₹473',
#  '₹4,999',
#  '₹1,324',
#  '₹549',
#  '₹209',
#  '₹657',
#  '₹2,520',
#  '₹1,329',
#  '₹3,850',
#  '₹597',
#  '₹1,739',
#  '₹699',
#  '₹389',
#  '₹419',
#  '₹449',
#  '₹449',
#  '₹2,640',
#  '₹1,709',
#  '₹439',
#  '₹439']

# %% [markdown]
# # question 7

# %%
driver = webdriver.Chrome(r"C:\Users\Kavisha\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
driver.get("https://www.amazon.in/")

# %%
designation = driver.find_element(By.XPATH,'//input[@class="nav-input nav-progressive-attribute"]')
designation.send_keys('Laptop')

# %%
search = driver.find_element(By.XPATH,'//input[@class="nav-input nav-progressive-attribute"]')
search.click()

# %%
filter1 = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[6]/li[10]/span/a/span')
filter1.click
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="fd923d8a82a1f0698f0efd10951acec2", element="5da38b48-3a24-4f22-9bf3-f85578c4a5f0")>>

# %%
lap_title = []
lap_rating = []
lap_price = []

# %%
laptop_title = driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in laptop_title[0:10]:
    laptop = i.text
    lap_title.append(laptop)

# %%
laptop_rating = driver.find_elements(By.XPATH,'//span[@class="a-size-base"]')
for i in laptop_rating[0:10]:
    laptop = i.text
    lap_rating.append(laptop)

# %%
laptop_price =driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in laptop_price[0:10]:
    laptop = i.text
    lap_price.append(laptop)

# %%
print(len(lap_title),len(lap_rating),len(lap_price))
# Out:
# 10 10 10

# %%
df7 = pd.DataFrame({'title':lap_title,'rating':lap_rating,'price':lap_price})
df7
# Out:
#                                                title rating     price
# 0  HP Pavilion x360 11th Gen Intel Core i7 14 inc...  (4.4)    82,490
# 1  Acer Swift 5 Intel Evo Premium 14 Inches Full ...  (4.2)  1,05,385
# 2  (Renewed) HP ProBook 430 G3 6th Gen Intel Core...  (3.3)    24,935
# 3  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...  (4.0)    95,546
# 4  Acer Nitro 5 Gaming Laptop Intel core i7 11th ...  (3.9)    79,990
# 5  (Renewed) HP ProBook 430 G3 6th Gen Intel Core...  (2.4)    22,999
# 6  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...  (4.2)    89,000
# 7  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...  (3.9)    57,990
# 8  ASUS VivoBook S S14 Intel Core i7-1165G7 11th ...  (4.3)    65,990
# 9  Fujitsu UH-X 11th Gen Intel Core i7 13.3” FHD ...  (4.4)    79,990

# %% [markdown]
# # question 8

# %%
driver = webdriver.Chrome(r"C:\Users\Kavisha\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
driver.get("https://www.azquotes.com/")

# %%
designation = driver.find_element(By.XPATH,'//input[@class="ui-autocomplete-input"]')
designation.send_keys('TOP 100 Quotes')

# %%
top = driver.find_element(By.XPATH,'//a[@class="gs-title"]')
top.click()

# %%
Quote_title = []
Author_name = []
Quotes_type = []

# %%
title_tags = driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in title_tags[0:100]:
    title = i.text
    Quote_title.append(title)

# %%
author_tags = driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author = i.text
    Author_name.append(author)

# %%
quote_tags = driver.find_elements(By.XPATH,'//div[@class="mytags"]')
for i in quote_tags[0:100]:
    quote= i.text
    Quotes_type.append(quote)

# %%
print(len(Quote_title),len(Author_name),len(Quotes_type))
# Out:
# 25 25 25

# %%
df8 = pd.DataFrame({'title':Quote_title,'author':Author_name,'type':Quotes_type})
df8
# Out:
#                                                 title                 author  \
# 0   It is the mark of an educated mind to be able ...              Aristotle
# 1               If you think you can't, you're right.            Carol Bartz
# 2        Be the trouble you want to see in the world.            Joey Comeau
# 3     The best thing you can do is follow your dreams                The Rev
# 4            Build what you want to see in the world.            Jack Dorsey
# 5   Living well is the best revenge.If opportunity...            Max Eastman
# 6       What we got here is a failure to communicate.            Paul Newman
# 7   Hokey religions and ancient weapons are no mat...          Harrison Ford
# 8   Plan ahead: It wasn't raining when Noah built ...        Richard Cushing
# 9   Twenty years from now you will be more disappo...  H. Jackson Brown, Jr.
# 10  Happiness is a way of travel – not a destination.         Roy M. Goodman
# 11     Be the change you want to see in your networks        James H. Fowler
# 12        If opportunity doesn't knock, build a door.           Milton Berle
# 13  When I stand before God at the end of my life,...           Erma Bombeck
# 14  Animation can explain whatever the mind of man...            Walt Disney
# 15    Be the compromise you want to see in the world.         Mahatma Gandhi
# 16  Choose a job you love, and you will never have...              Confucius
# 17  All your dreams can come true if you have the ...            Walt Disney
# 18  You cannot be lonely if you like the person yo...             Wayne Dyer
# 19   People will never forget how you made them feel.           Maya Angelou
# 20  Definiteness of purpose is the starting point ...       W. Clement Stone
# 21  A person who never made a mistake never tried ...        Albert Einstein
# 22  I've learned that people will forget what you ...           Maya Angelou
# 23  Great spirits have always encountered violent ...        Albert Einstein
# 24  The difference between ordinary and extraordin...          Jimmy Johnson
#
#                                        type
# 0   Inspirational, Motivational, Leadership
# 1            Inspirational, Positive, Smart
# 2       Inspirational, Motivational, Change
# 3            Motivational, Change, Positive
# 4       Inspirational, Motivational, Change
# 5   Inspirational, Motivational, Graduation
# 6     Movie, Communicate, All Time Greatest
# 7                      War, Kids, Your Side
# 8       Inspirational, Rain, Planning Ahead
# 9         Inspirational, Life, Motivational
# 10       Inspirational, Positive, Happiness
# 11      Inspirational, Motivational, Change
# 12      Inspirational, Motivational, Change
# 13        Inspirational, Life, Motivational
# 14    Inspirational, Motivational, Positive
# 15      Inspirational, Motivational, Change
# 16                Love, Inspirational, Life
# 17        Inspirational, Life, Motivational
# 18               Confidence, Lonely, Clever
# 19    Inspirational, Motivational, Positive
# 20    Inspirational, Motivational, Positive
# 21      Inspirational, Motivational, Change
# 22        Inspirational, Life, Motivational
# 23    Inspirational, Motivational, Positive
# 24    Inspirational, Motivational, Positive
